# %% [markdown]
# # News Articles Clustering
# ## Name: Kuan-Cheng Fu

# %% [markdown]
# ## Chapter 1 Introduction
# In this project, we will be working with **about 15,000 articles** which are from **N categories**. Therefore, the goal of this project is to develop a framework which is capable of clustering articles based on their text contents.
# Basically, we will apply several techniques such as TFIDF, cosine similarity, truncated SVD, and k-means clustering
# to this project.

# %%
# Import package
import numpy as np
import pandas as pd 
import nltk
import re
import string
import scipy.sparse as sp
import matplotlib.pyplot as plt
from sklearn.preprocessing import normalize
from sklearn.decomposition import TruncatedSVD
from sklearn.cluster import KMeans 
from sklearn.metrics import silhouette_score
from sklearn.metrics import pairwise_distances_argmin_min
from sklearn.metrics.pairwise import cosine_similarity

# %%
# Load data
raw_articles_data = pd.read_csv('data/articles_raw.csv')
raw_articles_data
# Out:
#             id                                              title  \
# 0      1247638  Triple W to Feature DFree at CES 2019 - First ...
# 1      1247639  Pundi X Coin Review: Should You Invest in the ...
# 2      1247641  Pundi X 1-Day Trading Volume Reaches $1.04 Mil...
# 3      1247642  Pundi X Hits Market Capitalization of $74.35 M...
# 4      1247643   Pundi X (NPXS) Market Cap Reaches $73.89 Million
# ...        ...                                                ...
# 11182  1388717                                                NaN
# 11183  1388718                                                NaN
# 11184  1388738  Intercellular is an Educational Experience Tak...
# 11185  1388746  Wonderfall Mixes VR and Actual Reality For An ...
# 11186  1388760   VR and AR Market Forecast and Future Projections
#
#                                                     text        date
# 0      jan. according to the u. s. national institute...  2019-01-03
# 1      the npxs token developer aim to have ethereum ...  2019-01-06
# 2      pundi x (currency:npxs) traded 2. u dollar dur...  2019-01-02
# 3      pundi x (currency:npxs) traded 0. pm eastern o...  2019-01-04
# 4      pundi x (currency:npxs) traded down 0. u dolla...  2019-01-03
# ...                                                  ...         ...
# 11182  microsoft for the mixed reality partnership pr...  2019-01-02
# 11183  ar (ar) app that convert any room to a virtual...  2019-01-09
# 11184  there nothing like a good educational vr (vr) ...  2019-02-13
# 11185  it got a lot of vr and ar exhibit right now, n...  2019-01-30
# 11186  immersive technology adoption rate have steadi...  2019-01-30
#
# [11187 rows x 4 columns]

# %% [markdown]
# ## Chapter 2 Framework
# ### 2.1 Text Processing and TF-IDF Matrix
# In this section, we first create a function to process and tokenize text contents. After that, we create a function to compute a sparse TFIDF matrix from the text contents. These functions will be executed step by step as follows.

# %%
# Create function to process and tokenize raw texts
def preprocess(text, stopwords={}, lemmatizer=nltk.stem.wordnet.WordNetLemmatizer()):
    # Lower case
    text = text.lower()
    # Handle URL
    text = re.sub(r"https?://t.co/\w{10}",' ', text)
    # Deal with "'s" 
    text = re.sub(r"'s", "", text)
    # Deal with "'" 
    translator2 = str.maketrans({key: None for key in string.punctuation[6]})
    text = text.translate(translator2) 
    # Deal with the rest of punctuations
    translator3 = str.maketrans(string.punctuation, ' '*len(string.punctuation))
    text = text.translate(translator3)
    # Handle unicode
    text = re.sub(r'[^\x00-\x7F]+',' ', text)
    # Split the text
    r1 = nltk.word_tokenize(text)
    # Lemmatize the text
    r2 = [lemmatizer.lemmatize(word) for word in r1]
    # Remove the stopwords
    r3 = [word for word in r2 if not word in stopwords]
    # Remove digits
    r4 = [word for word in r3 if word.isalpha()]
    return r4

# %%
# Import NLTK stopwords
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('punkt')
extra_stopwords = set()
stopwords = set(nltk.corpus.stopwords.words('english')) | extra_stopwords
# Out:
# [nltk_data] Downloading package stopwords to /Users/fufu/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /Users/fufu/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package punkt to /Users/fufu/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
# Put the preprocessed texts into a list
articles = []
for i in range(0,raw_articles_data.shape[0]):
    tokenized_text = preprocess(raw_articles_data['text'][i], stopwords)
    articles.append(' '.join(tokenized_text))

# %%
# Create function to build a sparse TFIDF matrix
def tfidf(docs):    
    document_words = [doc.split() for doc in docs]
    vocab = sorted(set(sum(document_words, [])))
    vocab_dict = {k:i for i,k in enumerate(vocab)}
    X_tf = np.zeros((len(docs), len(vocab)), dtype=int)
    for i,doc in enumerate(document_words):
        for word in doc:
            X_tf[i, vocab_dict[word]] += 1
            
    idf = np.log(X_tf.shape[0]/X_tf.astype(bool).sum(axis=0))
    X_tfidf = X_tf * idf
    tfidf = sp.csr_matrix(X_tfidf)
    all_words = vocab
    return(tfidf,all_words)

# %%
# Compute a TFIDF matrix for the texts and normalize the matrix
X_tfidf, words = tfidf(articles)
tf_idf_norm = normalize(X_tfidf)

# %% [markdown]
# ### 2.2 Dimensionality Reduction and Clustering (1)
# After having the normalized TFIDF matrix, the dimensionality reduction will be performed using truncated SVD with 100 components. Next, we create a function to select optimal k value of k-means clustering using silhouette method. Finally, we create a function to cluster the articles using k-means clustering with k clusters and further plot the position of the articles in 2D space.

# %%
# Perform dimensionality reduction on the normalized TFIDF matrix by using truncated SVD
svd_model = TruncatedSVD(n_components=100, algorithm='randomized')
svd_matrix = svd_model.fit_transform(tf_idf_norm)

# %%
# Create function to select the optimal k value of k-means clustering with silhouette method
def plot_sil(df, kmax=30): 
    sil = []
    for k in range(2, kmax+1):
        kmeans = KMeans(n_clusters=k, max_iter=600, algorithm='auto').fit(df)
        labels = kmeans.labels_
        sil.append(silhouette_score(df, labels, metric='euclidean')) 

    plt.plot(range(2, kmax+1), sil)
    plt.xlabel('Number of Clusters')
    plt.ylabel('Score')
    plt.title('Silhouette Method')
    plt.grid()
    plt.show()

# %%
# Determine the optimal k value by identifying the highest score
random_state=0xCAFE
plot_sil(svd_matrix, kmax=30)

# %%
# Create function to cluster the texts and plot the position of the texts in 2D space 
def plot_and_predict(df, n_clusters=2, random_state=0xCAFE):

    kmeans = KMeans(n_clusters=n_clusters, max_iter=600, algorithm='auto')
    fitted = kmeans.fit(df)
    prediction = kmeans.predict(df)
    
    plot_matrix = TruncatedSVD(n_components=2, algorithm='randomized', random_state=random_state).fit_transform(df)
    
    fig, ax = plt.subplots(figsize=(12,6))
    for c in range(n_clusters):
        ax.scatter(plot_matrix[prediction==c][:,0], plot_matrix[prediction==c][:,1], label=c, alpha=0.8, edgecolors='none')

    ax.legend()
    ax.grid(True)
    plt.show()
    
    return prediction

# %%
# Show the clustering result in 2D space 
prediction = plot_and_predict(svd_matrix, n_clusters=2)

# %%
# Show the raw texts in these two groups
n_clusters = 2
for i in range(n_clusters):
    print('%d, The raw texts in group %d:'%(i,i))
    result = raw_articles_data[prediction==i]['text']   
    display(result)
# Out:
# 0, The raw texts in group 0:
# 0        jan. according to the u. s. national institute...
# 1        the npxs token developer aim to have ethereum ...
# 2        pundi x (currency:npxs) traded 2. u dollar dur...
# 3        pundi x (currency:npxs) traded 0. pm eastern o...
# 4        pundi x (currency:npxs) traded down 0. u dolla...
#                                ...
# 11182    microsoft for the mixed reality partnership pr...
# 11183    ar (ar) app that convert any room to a virtual...
# 11184    there nothing like a good educational vr (vr) ...
# 11185    it got a lot of vr and ar exhibit right now, n...
# 11186    immersive technology adoption rate have steadi...
# Name: text, Length: 11078, dtype: object
# 1, The raw texts in group 1:
# 256      please read the rule before joining the discus...
# 379      please read the rule before joining the discus...
# 383      please read the rule before joining the discus...
# 634      please read the rule before joining the discus...
# 635      please read the rule before joining the discus...
#                                ...
# 9933     please read the rule before joining the discus...
# 10109    please read the rule before joining the discus...
# 10117    please read the rule before joining the discus...
# 10230    please read the rule before joining the discus...
# 10578    please read the rule before joining the discus...
# Name: text, Length: 109, dtype: object

# %% [markdown]
# ### Summary
# We find that all the articles are same in group 1. Therefore, we decide to regard the articles in group 1 as outliers and not pick the representative article for group 1. Then, we will keep clustering the articles in group 0 in the next section.

# %% [markdown]
# ### 2.3 Dimensionality Reduction and Clustering (2)
# ### Part A
# Since the articles in group 1 are regarded as the outliers, we will first remove those articles from our dataset. After that, we will keep utilzing the function created in Section 2.2 to select optimal k value of k-means clustering, cluster the articles in group 0 using k-means clustering with k clusters, and further plot the position of the articles in group 0 in 2D space.

# %%
# Deal with the same articles in group 1
index, = np.where(prediction==0)
new_raw_articles_data = raw_articles_data.iloc[index].reset_index(drop=True)

tf_idf_norm_step2 = tf_idf_norm[prediction==0]
svd_matrix_step2 = TruncatedSVD(n_components=100, algorithm='randomized', random_state=0xCAFE).fit_transform(tf_idf_norm_step2)

# %%
# Determine the optimal k value by identifying the highest score
random_state=0xCAFE
plot_sil(svd_matrix_step2, kmax=30)

# %%
# Show the clustering result in 2D space 
prediction2 = plot_and_predict(svd_matrix_step2, n_clusters=2)

# %%
# Show the raw texts in these two groups
n_clusters = 2
for i in range(n_clusters):
    print('%d, The raw texts in group %d:'%(i,i))
    result = raw_articles_data[prediction==0][prediction2==i]['text']   
    display(result)
# Out:
# 0, The raw texts in group 0:
# 1        the npxs token developer aim to have ethereum ...
# 2        pundi x (currency:npxs) traded 2. u dollar dur...
# 3        pundi x (currency:npxs) traded 0. pm eastern o...
# 4        pundi x (currency:npxs) traded down 0. u dolla...
# 5        pundi x nem (currency:npxsxem) traded down 10....
#                                ...
# 11126    pundi x (currency:npxs) traded down 1. u. s. p...
# 11127    pundi x nem (currency:npxsxem) traded 1. pm ea...
# 11128    pundi x nem (currency:npxsxem) traded down 7. ...
# 11129    pundi x nem (currency:npxsxem) traded 0. am et...
# 11130    pundi x nem (currency:npxsxem) traded 6. u dol...
# Name: text, Length: 1375, dtype: object
# 1, The raw texts in group 1:
# 0        jan. according to the u. s. national institute...
# 10       ce 2019 officially start on tuesday and press ...
# 14       vr gaming. weve had highlight like creed, fire...
# 15       the industry summary is provided by the analys...
# 16       we use cooky and other technology to customize...
#                                ...
# 11182    microsoft for the mixed reality partnership pr...
# 11183    ar (ar) app that convert any room to a virtual...
# 11184    there nothing like a good educational vr (vr) ...
# 11185    it got a lot of vr and ar exhibit right now, n...
# 11186    immersive technology adoption rate have steadi...
# Name: text, Length: 9703, dtype: object

# %% [markdown]
# ### Summary
# After removing the outliers and reviewing the new clustering result, we find that the articles in group 0 seem to come from the same category regarding cryptocurrency. Therefore, we decide to further analyze the articles in group 0 in the next part. On the other hand, we will keep clustering the articles in group 1 in Section 2.4.

# %% [markdown]
# ### Part B
# Regarding the articles in group 0, we first pick the article whose position is most close to the cluster center as representative. Next, regarding the representative article, we select the words with top-5 highest TFIDF scores as top-5 keywords. After that, we select the articles with top-10 highest sum of TFIDF scores regarding the top-5 keywords as top-10 documents. Then, we select the articles with top-10 highest cosine similarities regarding representative article as top-10 documents. Finally, we select the articles with top-10 highest cosine similarities only calculated by top-5 keywords as top-10 documents.

# %%
# Find cluster centers
random_state = 0xCAFE
kmeans = KMeans(n_clusters=2, max_iter=600, algorithm='auto')
fitted = kmeans.fit(svd_matrix_step2)
pred = kmeans.predict(svd_matrix_step2)
centers = fitted.cluster_centers_

# %%
# Choose article whose position is most close to the cluster center as representative
closest, _ = pairwise_distances_argmin_min(centers, svd_matrix_step2)
representative_article = new_raw_articles_data['text'][closest[0]]
new_raw_articles_data['title'][closest[0]]
# Out:
# 'What Is Tether? - Everything You Need To Know About Tether Cryptocurrency'

# %%
# Choose words with top-5 highest TFIDF scores as top-5 keywords
tf_idf_array = tf_idf_norm_step2.toarray()
top5_index = tf_idf_array[closest[0]].argsort()[-5:][::-1]
top5_words = list(np.array(words)[top5_index.tolist()])
top5_words
# Out:
# ['tether', 'bitfinex', 'dollar', 'eur', 'currency']

# %%
# choose articles with top-10 highest sum of TFIDF scores regarding the top-5 keywords as top-10 documents
sum_tfidf = np.sum(tf_idf_array[:,top5_index],axis=1)
top10_index = sum_tfidf.argsort()[-10:][::-1]
top_articles_q3 = np.array(new_raw_articles_data['text'][top10_index]).tolist()
new_raw_articles_data['title'][top10_index]
# Out:
# 570     What Is Tether? - Everything You Need To Know ...
# 7716      What is a fiat-backed stablecoin? - Coininsider
# 5702    How to Read Currency Pairs: Forex Quotes Expla...
# 8268    Bitcoin (BTC) Latest Update: Bitcoin (BTC) Mig...
# 9944                       Cycle Trading: Dollar Rejected
# 9592    Bexplus Investment Advice - Profit from Bitcoi...
# 2224    If Bitcoin Becomes a Store of Value Then it Wi...
# 6715    USD/CAD Forms Textbook Bear Flag Pattern, 1.31...
# 9260    Bitcoin [BTC] dominated by stablecoins with re...
# 2563    Binance Now Trading Cryptos, EUR and GBP at Je...
# Name: title, dtype: object

# %%
# choose articles with top-10 highest cosine similarities regarding representative article as top-10 documents
c_matrix = cosine_similarity(tf_idf_norm_step2)
array1 = np.squeeze(np.asarray(c_matrix))[closest[0]]
array2 = np.where(array1 > 0)[0]
top10_index2 = array1[array2].argsort()[-10:][::-1]
top_articles_q4 = np.array(new_raw_articles_data['text'][array2[top10_index2]]).tolist()
new_raw_articles_data['title'][array2[top10_index2]]
# Out:
# 570     What Is Tether? - Everything You Need To Know ...
# 7716      What is a fiat-backed stablecoin? - Coininsider
# 9260    Bitcoin [BTC] dominated by stablecoins with re...
# 374     New crypto exchange takes on behemoths with ph...
# 225     Physical Bitcoin Futures Are Coming to Asia Fi...
# 566            Top 10 Crypto Projects by Tech Development
# 1144                                                  NaN
# 588     Top 10 Expectations from the Cryptocurrency Ec...
# 6482    Crypto Market Wrap: Tron Surges to Seventh, Fl...
# 9559       Novem To Launch Gold Pegged Stablecoin ‘999.9’
# Name: title, dtype: object

# %%
# choose articles with top-10 highest cosine similarities only calculated by top-5 keywords as top-10 documents
c_matrix = cosine_similarity(tf_idf_norm_step2[:,top5_index])
array1 = np.squeeze(np.asarray(c_matrix))[closest[0]]
array2 = np.where(array1 > 0)[0]
top10_index3= array1[array2].argsort()[-10:][::-1]
top_articles_q5 = np.array(new_raw_articles_data['text'][array2[top10_index3]]).tolist()
new_raw_articles_data['title'][array2[top10_index3]]
# Out:
# 570      What Is Tether? - Everything You Need To Know ...
# 1701     USB-C VR Extension Adapter for Rift & Windows ...
# 2968               Drones Create Quite the “Splash” at CES
# 5937     Five smart ways to use wearable technology in ...
# 566             Top 10 Crypto Projects by Tech Development
# 10486    Exclusive: HP's Next-gen VR Headset Aims to Ra...
# 6460     An In-Depth Look at the Trezor Model T Hardwar...
# 225      Physical Bitcoin Futures Are Coming to Asia Fi...
# 218      Circle Reveals $24 Billion Cryptocurrency OTC ...
# 2739     Hard Fork Countdown: Ethereum’s Thirdening Dra...
# Name: title, dtype: object

# %%
# Create a dictionary with the above results
Results_Dict = {'Category 1': [representative_article, top5_words, top_articles_q3, top_articles_q4, top_articles_q5]}

# %% [markdown]
# ### Summary
# After the brief analysis, we create a dictionary with all the results toward the group 0. On the other hand, according to the summary of Part A, we will keep clustering the articles in group 1 in the next section.

# %% [markdown]
# ### 2.4 Dimensionality Reduction and Clustering (3)
# ### Part A
# Since the articles in group 0 are regarded as coming from the same category, we will then remove those articles from our dataset. After that, we will keep utilzing the function created in Section 2.2 to select optimal k value of k-means clustering, cluster the articles in group 1 using k-means clustering with k clusters, and further plot the position of the articles in group 1 in 2D space.

# %%
# Deal with the articles in group 0
index, = np.where(prediction2==1)
new_raw_articles_data2 = new_raw_articles_data.iloc[index].reset_index(drop=True)

tf_idf_norm_step3 = tf_idf_norm_step2[prediction2==1]
svd_matrix_step3 = TruncatedSVD(n_components=100, algorithm='randomized', random_state=0xCAFE).fit_transform(tf_idf_norm_step3)

# %%
# Determine the optimal k value by identifying the highest score
random_state=0xCAFE
plot_sil(svd_matrix_step3, kmax=10)

# %%
# Show the clustering result in 2D space 
prediction3 = plot_and_predict(svd_matrix_step3, n_clusters=2)

# %%
# Show the raw texts in these two groups
n_clusters = 2
for i in range(n_clusters):
    print('%d, The raw texts in group %d:'%(i,i))
    result = raw_articles_data[prediction==0][prediction2==1][prediction3==i]['text'] 
    display(result)
# Out:
# 0, The raw texts in group 0:
# 949      gamesradar+ is part of future plc, an internat...
# 953      gamesradar+ is part of future plc, an internat...
# 955      gamesradar+ is part of future plc, an internat...
# 957      gamesradar+ is part of future plc, an internat...
# 959      gamesradar+ is part of future plc, an internat...
#                                ...
# 10522    pc gamer is part of future plc, an internation...
# 10523    pc gamer is part of future plc, an internation...
# 10524    pc gamer is part of future plc, an internation...
# 11076    what hi fi? future plc, an international mediu...
# 11176    techradar is part of future plc, an internatio...
# Name: text, Length: 93, dtype: object
# 1, The raw texts in group 1:
# 0        jan. according to the u. s. national institute...
# 10       ce 2019 officially start on tuesday and press ...
# 14       vr gaming. weve had highlight like creed, fire...
# 15       the industry summary is provided by the analys...
# 16       we use cooky and other technology to customize...
#                                ...
# 11182    microsoft for the mixed reality partnership pr...
# 11183    ar (ar) app that convert any room to a virtual...
# 11184    there nothing like a good educational vr (vr) ...
# 11185    it got a lot of vr and ar exhibit right now, n...
# 11186    immersive technology adoption rate have steadi...
# Name: text, Length: 9610, dtype: object

# %% [markdown]
# ### Summary
# After reviewing the new clustering result, we find that the articles in group 0 seem to come from the same category regarding games and technology. Therefore, we decide to further analyze the articles in group 0 in the next part. On the other hand, we could keep clustering the articles in group 1 since the articles in group 1 seem to come from the different categories.

# %% [markdown]
# ### Part B
# Similarly, regarding the articles in group 0, we first pick the article whose position is most close to the cluster center as representative. Next, regarding the representative article, we select the words with top-5 highest TFIDF scores as top-5 keywords. After that, we select the articles with top-10 highest sum of TFIDF scores regarding the top-5 keywords as top-10 documents. Then, we select the articles with top-10 highest cosine similarities regarding representative article as top-10 documents. Finally, we select the articles with top-10 highest cosine similarities only calculated by top-5 keywords as top-10 documents.

# %%
# Find cluster centers
random_state = 0xCAFE
kmeans = KMeans(n_clusters=2, max_iter=600, algorithm='auto')
fitted = kmeans.fit(svd_matrix_step3)
pred = kmeans.predict(svd_matrix_step3)
centers = fitted.cluster_centers_

# %%
# Choose article whose position is most close to the cluster center as representative
closest, _ = pairwise_distances_argmin_min(centers, svd_matrix_step3)
representative_article = new_raw_articles_data2['text'][closest[0]]
new_raw_articles_data2['title'][closest[0]]
# Out:
# 'Roku’s free streaming service is now available on iOS devices'

# %%
# Choose words with top-5 highest TFIDF scores as top-5 keywords
tf_idf_array = tf_idf_norm_step3.toarray()
top5_index = tf_idf_array[closest[0]].argsort()[-5:][::-1]
top5_words = list(np.array(words)[top5_index.tolist()])
top5_words
# Out:
# ['techradar', 'plc', 'future', 'publisher', 'international']

# %%
# choose articles with top-10 highest sum of TFIDF scores regarding the top-5 keywords as top-10 documents
sum_tfidf = np.sum(tf_idf_array[:,top5_index],axis=1)
top10_index = sum_tfidf.argsort()[-10:][::-1]
top_articles_q3 = np.array(new_raw_articles_data2['text'][top10_index]).tolist()
new_raw_articles_data2['title'][top10_index]
# Out:
# 7944    iPhone 11 reportedly not getting a fast-chargi...
# 4411    Samsung is switching to eco-friendly phone pac...
# 7946    Microsoft might not be killing off Paint after...
# 7943    Adobe gives Lightroom a boost with Sensei-powe...
# 7942    Official Samsung Galaxy S10 cases leak as the ...
# 9692    Pimax’s ‘8K’ ultra-wide high-resolution VR hea...
# 4412    Serious Apple glitch lets users snoop on peopl...
# 4413    Today-only: cheap Chromebooks, gaming PC and m...
# 4408    Roku’s free streaming service is now available...
# 3155                           Steam now has 30,000 games
# Name: title, dtype: object

# %%
# choose articles with top-10 highest cosine similarities regarding representative article as top-10 documents
c_matrix = cosine_similarity(tf_idf_norm_step3)
array1 = np.squeeze(np.asarray(c_matrix))[closest[0]]
array2 = np.where(array1 > 0)[0]
top10_index2 = array1[array2].argsort()[-10:][::-1]
top_articles_q4 = np.array(new_raw_articles_data2['text'][array2[top10_index2]]).tolist()
new_raw_articles_data2['title'][array2[top10_index2]]
# Out:
# 7944    iPhone 11 reportedly not getting a fast-chargi...
# 4408    Roku’s free streaming service is now available...
# 4413    Today-only: cheap Chromebooks, gaming PC and m...
# 7942    Official Samsung Galaxy S10 cases leak as the ...
# 7943    Adobe gives Lightroom a boost with Sensei-powe...
# 7946    Microsoft might not be killing off Paint after...
# 4411    Samsung is switching to eco-friendly phone pac...
# 9692    Pimax’s ‘8K’ ultra-wide high-resolution VR hea...
# 4412    Serious Apple glitch lets users snoop on peopl...
# 5710    Farming Simulator goes esports with a €250,000...
# Name: title, dtype: object

# %%
# choose articles with top-10 highest cosine similarities only calculated by top-5 keywords as top-10 documents
c_matrix = cosine_similarity(tf_idf_norm_step3[:,top5_index])
array1 = np.squeeze(np.asarray(c_matrix))[closest[0]]
array2 = np.where(array1 > 0)[0]
top10_index3= array1[array2].argsort()[-10:][::-1]
top_articles_q5 = np.array(new_raw_articles_data2['text'][array2[top10_index3]]).tolist()
new_raw_articles_data2['title'][array2[top10_index3]]
# Out:
# 7943    Adobe gives Lightroom a boost with Sensei-powe...
# 7944    iPhone 11 reportedly not getting a fast-chargi...
# 7942    Official Samsung Galaxy S10 cases leak as the ...
# 9692    Pimax’s ‘8K’ ultra-wide high-resolution VR hea...
# 4411    Samsung is switching to eco-friendly phone pac...
# 4413    Today-only: cheap Chromebooks, gaming PC and m...
# 4408    Roku’s free streaming service is now available...
# 7946    Microsoft might not be killing off Paint after...
# 4412    Serious Apple glitch lets users snoop on peopl...
# 5711    Play Stormdivers, Housemarque's battle royale,...
# Name: title, dtype: object

# %%
# Add the above results to the dictionary
Results_Dict['Category 2'] = [representative_article, top5_words, top_articles_q3, top_articles_q4, top_articles_q5]

# %% [markdown]
# ### Summary
# After the brief analysis about group 0, we add all the results toward the group 0 to the dictionary created in Part B of Section 2.3.

# %% [markdown]
# ## Chapter 3 Conclusion and Answering Questions
# Apparently, we didn't finish our work. According to the summary in Part A of Section 2.4, we should keep clustering the articles since the rest articles seem to come from the different categories. However, we did provide a framework to deal with this kind of text clustering problem.
#
# So far, we already identified two categories out of the articles. One category is about cryptocurrency (Category 1) while another one is about games and technology (Category 2). Most importanly, we stored the analysis results of each category in a dictionary called `Results_Dict`. Therefore, on the basis of the dictionary, we could try to answer the following questions.

# %% [markdown]
# Q1: Please plot the position of the articles in two dimensional space and cluster the articles in several groups. Then, you need to pick the representative article toward each group. (note: you have to explain the reason of picking group number)
#
# Ans: We plot the position of the articles in 2D space and cluster the articles in several groups by using truncated SVD and k-means clustering, which could be found in Chapter 2. Beside, we pick group number by using silhouette method, which could also be found in Chapter 2. Regarding the representative article toward each group, if now we want to know the representative article of Category 1, we could execute the code as follows:

# %%
Results_Dict['Category 1'][0]
# Out:
# "born with the idea of having a stable cryptocurrency that can be used a digital dollars, tether is a cryptocurrency with a value meant to mirror the value the u. s. tether is a cryptocurrency with token issued by tether limited, and claim to be backed up by u. s. tether platform. tether which come with the trading abbreviation usdt, belongs to a group of cryptocurrency, with which one can transfer amount in real time and exchange them with other currencies. tether is supported by several blockchain platform such a kraken and bitfinex. it is also one of the stable coin because it act a an alternative to u. s. it act a a stable dollar for many exchanges, and is also one of the most stable option available. unlike other cryptocurrency, tether is supposed to be backed by dollar kept in reserve in a 1:1 ratio, which is a big selling point, and a big problem in the untethered and decentralized crypto arena. although it claim to trade at $1 on all exchanges, the actual price seems to fluctuate a little. it all started with j. r. willett publishing a paper in 2012 stating the possibility of new currency on top of the bitcoin protocol. tether cryptocurrency one of the original member of mastercoin foundation, brock pierce, would become a co founder of tether. craig sellars, cto of mastercoin, would also become one of the co founders of tether. in july 2014, they launched realcoin, which wa the precursor to tether. after releasing the first coin in october 2014, one of the founders, reeve collins announced in november 2014, that the project wa being renamed to tether. in early 2015, bitfinex enabled trading with tether on their platform. while tether and bitfinex have always stated that they are separate companies, the paradise paper in 2017, leaked that bitfinex official philip potter and giancarlo devasini are responsible for helping the setup of a the company tether holding limited in the british virgin island in 2014. later, a spokesperson for bitfinex and tether said that the ceo of both firm is jan ludovicus van der velde. initially, tether had been processing u dollar transaction through taiwanese banks, which transferred the money through the well fargo bank which allowed the fund to move outside taiwan. in april 2017, according to tether, these international transfer were blocked. in 2017, the omni foundation and charlie lee announced that tether would issue on the omni layer of cryptocurrency. united state dollar and euro on the ethereum blockchain. tether later gave the confirmation that the ethereum token were issued. at present, there exists a total of four distinct tether token namely, the united state dollar tether and the euro tether present on bitcoin's omni layer, the united state dollar tether and the euro tether present a an erc 20 token. a of september 2018, the number of tether grew to about $2. by the summer of 2018, it accounted for up to 80% of bitcoin volume. in october 2018, the price of tether fell to $0. bitfinex exchanged tether for bitcoin, driving it price up. tether is a digital to fiat currency and it can be easily traded at bitfinex, kraken, shapeshift and many other exchange easily. you can easily convert real world u dollar (usd), euro (eur), and japanese yen (jpy), to their equivalent digital token or crypto tether usd, tether eur, and tether jpy and then use them in any digital platform that allows cryptocurrency and support tether. unlike bitcoin and other cryptos, the exchange rate is stable always at 1:1 for all fiat currency that it supports, which is a good thing regardless of whether you want to convert your bank real world money into crypto or otherwise, since tether token can also be redeemed for cash. sending tether to tether wallet ha always been free. the company also offer decentralized exchange, browser based, open source, wallet encryption. but before using tether, there are a few thing that you should know and understand. buried deep within the term of service of tether agreement do ...

# %% [markdown]
# Q2: Based on the Q1, what are the top-5 keywords of each representative article.
#
# Ans: If now we want to know the top-5 keywords of the representative article of Category 1, we could execute the code as follows:

# %%
Results_Dict['Category 1'][1]
# Out:
# ['tether', 'bitfinex', 'dollar', 'eur', 'currency']

# %% [markdown]
# Q3: Based on the Q1 and Q2, please rank the top-10 document order with the top-5 keywords from the representative article toward each group.
#
# Ans: If now we want to know the top-10 document order with the top-5 keywords from the representative article toward Category 1, we could execute the code as follows:

# %%
Results_Dict['Category 1'][2]
# Out:
# ["born with the idea of having a stable cryptocurrency that can be used a digital dollars, tether is a cryptocurrency with a value meant to mirror the value the u. s. tether is a cryptocurrency with token issued by tether limited, and claim to be backed up by u. s. tether platform. tether which come with the trading abbreviation usdt, belongs to a group of cryptocurrency, with which one can transfer amount in real time and exchange them with other currencies. tether is supported by several blockchain platform such a kraken and bitfinex. it is also one of the stable coin because it act a an alternative to u. s. it act a a stable dollar for many exchanges, and is also one of the most stable option available. unlike other cryptocurrency, tether is supposed to be backed by dollar kept in reserve in a 1:1 ratio, which is a big selling point, and a big problem in the untethered and decentralized crypto arena. although it claim to trade at $1 on all exchanges, the actual price seems to fluctuate a little. it all started with j. r. willett publishing a paper in 2012 stating the possibility of new currency on top of the bitcoin protocol. tether cryptocurrency one of the original member of mastercoin foundation, brock pierce, would become a co founder of tether. craig sellars, cto of mastercoin, would also become one of the co founders of tether. in july 2014, they launched realcoin, which wa the precursor to tether. after releasing the first coin in october 2014, one of the founders, reeve collins announced in november 2014, that the project wa being renamed to tether. in early 2015, bitfinex enabled trading with tether on their platform. while tether and bitfinex have always stated that they are separate companies, the paradise paper in 2017, leaked that bitfinex official philip potter and giancarlo devasini are responsible for helping the setup of a the company tether holding limited in the british virgin island in 2014. later, a spokesperson for bitfinex and tether said that the ceo of both firm is jan ludovicus van der velde. initially, tether had been processing u dollar transaction through taiwanese banks, which transferred the money through the well fargo bank which allowed the fund to move outside taiwan. in april 2017, according to tether, these international transfer were blocked. in 2017, the omni foundation and charlie lee announced that tether would issue on the omni layer of cryptocurrency. united state dollar and euro on the ethereum blockchain. tether later gave the confirmation that the ethereum token were issued. at present, there exists a total of four distinct tether token namely, the united state dollar tether and the euro tether present on bitcoin's omni layer, the united state dollar tether and the euro tether present a an erc 20 token. a of september 2018, the number of tether grew to about $2. by the summer of 2018, it accounted for up to 80% of bitcoin volume. in october 2018, the price of tether fell to $0. bitfinex exchanged tether for bitcoin, driving it price up. tether is a digital to fiat currency and it can be easily traded at bitfinex, kraken, shapeshift and many other exchange easily. you can easily convert real world u dollar (usd), euro (eur), and japanese yen (jpy), to their equivalent digital token or crypto tether usd, tether eur, and tether jpy and then use them in any digital platform that allows cryptocurrency and support tether. unlike bitcoin and other cryptos, the exchange rate is stable always at 1:1 for all fiat currency that it supports, which is a good thing regardless of whether you want to convert your bank real world money into crypto or otherwise, since tether token can also be redeemed for cash. sending tether to tether wallet ha always been free. the company also offer decentralized exchange, browser based, open source, wallet encryption. but before using tether, there are a few thing that you should know and understand. buried deep within the term of service of tether agreement d ...
#  'stablecoins act a a cryptocurrency tied to the price of national currency. in this, we explore the fundamental of a fiat backed stablecoin. cryptocurrency are praised for paving the way for decentralized, peer to peer method of tender and blockchain based currency are promising to take electronic money to the next level. there are several obstacle which are blocking the path to widespreadadoptionand might hinder the support that national government have regarding cryptocurrency. one of the biggest issue that token face is the extreme volatility of market capitalization and price swings. a stablecoin is a cryptocurrency token which ha it value pegged at a 1:1 to a stable asset, such a gold or a fiat currency like the u dollar. the fundamental point of a stablecoin is to hold it pegged value, despite the twist and turn of volatility that the cryptocurrency market face otherwise. while cryptocurrency backed and non collateralized stablecoins exist and are gaining traction, the most common and by far the most well known stablecoins are the fiat backed cryptocurrency; pegged to a national currency. a the name implies, fiat stablecoins are token which are associated with the value of a particular fiat currency. usually,these token are based on the u dollar and hold their value fixed at a 1:1 ratio. arguably the most well known stablecoin and at the time of writing one of the top ten cryptocurrency, tether is pegged to the u dollar. daily, tether see an average trading volume of $4 billion usd, making it the largest stablecoin in daily volume and market cap. tether ha a close association with cryptocurrency exchange bitfinex, sharing the same cep. tether ha gained a lot of criticism owing to it lack of transparency in it methodology, a well a the lack of any official auditing of the token. this, in addition to centralization issue that arise despite the decentralized nature of cryptocurrency. usdt tokens. however, there are some controversy surrounding tether a there is a lack of transparency in whether usdt is fully backed by the equivalent fiat reserves. while tether claim that their usd fiat reserve are sufficient to back all the issued usdt token on a 1 to 1 basis, many critic have been challenging this claim. many critic believe tether company ha issued more usdt token than it dollar reserve in it bank account. they also claim that tether management team have been artificially pumping bitcoin price with all the newly printed tethers. where tether get criticized for it lack of transparency and centralization, trueusd get praise for being open in their legal operations. the trueusd team ha also set up an escrow account to which they have no access for user to exchange u dollar into tusd tokens. this alleviates claim of centralization and the smart contract in place also help in maintaining the 1 u dollar: 1 tusd ratio. the paxos standard wa founded in 2012 by paxos trust company. the stablecoin exists on ethereums blockchain a an erc 20 token and can be stored in any erc 20 compatible wallet. a paxos is pegged to the u dollar, pax token can only exist in circulation while corresponding dollar are held in reserve. if the pax token are exchanged to dollars, the corresponding stablecoins are destroyed to avoid any fluctuation in price. the gemini dollar is backed and founded by the winklevoss twin cryptocurrency gemini. the token is therefore issued by gemini trust company, llc, a new york trust company and ha been allowed and is regulated by the new yorkstate department of financial services. the gemini dollar also exists a an erc 20 token and one token is redeemable for $ 1 usd on the gemini exchange. start trading cryptocurrency with coindirect. internet writer looking to find the right piece. also present thing on radio and happens to be a chip off the old blockchain. coininsider is the authority on blockchain; providing breaking news bulletins, incisive opinion, market analysis, and regulatory updates.',
#  "we use a range of cooky to give you the best possible browsing experience. by continuing to use this website, you agree to our use of cookies. get the best part of dailyfx. id like to receive information from dailyfx and ig about trading opportunity and their product and service via email. but don't just read our analysis put it to the rest. ig, so you can try out trading with zero risk. we'll email you login detail shortly. an error occurred submitting your form. please try again later. forex quote reflect the price of different currency at any point in time. since a trader profit or loss is determined by movement in price (the quote), it is essential to develop a sound understanding of how to read currency pairs. a forex quote is the price of one currency in term of another currency. these quote always involve currency pair because you are buying one currency by selling another. the following section will expand on the different aspect of a forex quote. the same quote will be used throughout this piece to keep the number consistent. the international organization for standardization (iso) develop and publish international standard and have applied this to global currencies. this mean each country currency is abbreviated to three letters. forex quote show two currencies, the base currency, which appears first and the quote or variable currency, which appears last. the price of the first currency is always reflected in unit of the second currency. this may seem confusing a it is only natural to think of bid in term of buying so just remember the bid/ask terminology is from the broker perspective. trader will always be looking to buy forex when the price is low and sell when the price rises; or sell forex in anticipation that the currency will depreciate and buy it back at a lower price in the future. the price to buy a currency will typically be more than the price to sell the currency. this difference is called the spread and is where the broker earns money for executing the trade. the eur/usd is the most widely traded currency pair, so it is no surprise that the spread in this example is 0. quote are often displayed in accordance with the home currency in mind i. a direct quote for trader in the us, looking to buy euros, will read eur/usd and will be relevant to u citizen a the quote is in usd. this direct quote will provide u citizen with the price of one euro, in term of their home currency which is 1. the indirect quote is essentially the inverse of the direct currency (1/direct quote = 0. it show the value of one unit of domestic currency in term of foreign currency. indirect quote can be useful to convert foreign currency purchase abroad into domestic currency. our interactive online course help you develop the skill of trading from the ground up. develop your trading knowledge with our expert led webinars and in person seminar on a huge range of topics. a demo account is intended to familiarize you with the tool and feature of our trading platform and to facilitate the testing of trading strategy in a risk free environment. result achieved on the demo account are hypothetical and no representation is made that any account will or is likely to achieve actual profit or loss similar to those achieved in the demo account. condition in the demo account cannot always reasonably reflect all of the market condition that may affect pricing and execution in a live trading environment. past performance is no indication of future results. dailyfx is the news and education website of ig group.",
#  'bitcoin (btc) ha been heavily lambasted by a lot of analyst and strategist over the past year. a lot of financial institution and bank dont like the digital currency because it seems to be disrupting their industry. however, bitcoin (btc) and it underlying technology blockchain are going nowhere, and a lot of firm and industry are beginning their numerous benefits. according to a report released by cnbc on the 6th of february, bitcoin (btc) could soon be experiencing a resurgence on wall street. this wa said by nikolaos panigirtzoglou global market strategist at jp morgan. this mean that the interest on bitcoin (btc) in wall street are likely to be revived in the near term. the stability that is currently being displayed by the digital currency market is paving the way for more participation by institutional investor in the near future. the digital currency market wa a new market. it went through a bubble phase and the burst. panigirtzoglou said that more company will be attracted to bitcoin (btc) and other digital currency a stability in the crypto market grow and a the underlying technology of bitcoin (btc) becomes more important. the strategist further stated that a revival in bitcoin (btc) may be year away, a regulator are pretty slow when it come to realizing the potential of the digital currency. over the past years, a lot of expert have predicted more participation from institutional investor on wall street would push much needed capital into the digital currency verse, especially after the digital currency market suffered a bear year last year. in june last year, charles hoskinson the co founder of cardano (ada) said that if wall street enters into the digital currency space, it would bring in ten of trillion of dollars. nevertheless, wall street ha put it digital currency plan on hold due to the continuous downward trend of the digital currency market, according to a report from last year. according to a report by bloomberg in late december, top firm in the financial industry such a goldman sachs (a banking giant), morgan stanley (a multinational financial service firm), and citigroup inc. jack dorsey the chief executive officer of twitter is still optimistic about the future of bitcoin (btc). according to reports, bitcoin (btc) is the only digital currency that dorsey owns. the ceo said that the digital currency had a great brand and that it is resilient. he said bitcoin (btc) is native to internet ideal and it is principled. dorsey also went to the extent to say that bitcoin (btc) will become the single currency of the world in the next ten years. the world will have a single currency, the internet will have just one currency. i personally believe that bitcoin (btc) will be that currency. at the time of writing, bitcoin (btc) is changing hand at $3,450 after an increase of le than one percent over the past twenty four hours. the current market cap of the digital currency is $59.',
#  'the dollar found support at the 200 day ma on jan 31st and printed an early, 14 day, dcl. the dollar rallied out of that dcl to close above the upper daily cycle band, confirming a new daily cycle and indicating a new intermediate cycle. tuesday. the dollar did print a new daily cycle high on tuesday. but the dollar wa rejected by the 97 level, a level that turned the dollar back in august and in october. this ea the parameter for forming a daily swing high. a break below 69. a peak on day 8 would set up a potential left translated daily cycle formation. and with the dollar in it timing band for a yearly cycle low, a left translated daily cycle formation would align with the dollar completing it yearly cycle decline. in the weekend report i plan to detail what the dollar would need to do to complete it yearly cycle decline.',
#  'most professional predict that after one year depreciation of the bitcoin market in 2018, the bitcoin price probable keep decline in 2019. if you buy 1 bitcoin in the spot trade market with 10000 dollar at the beginning of 2018, your bitcoin may only value 3600 dollar at present. in bitcoin bear market, the only way to earn your value back is to trade your bitcoins to other altcoins and when the altcoin price rises, you can trade back to bitcoins to expand the number of your bitcoins. however, same a bitcoin, all the cryptocurrency are devalued. it ha a higher risk to invest altcoins which the price of altcoins fall even further. you may have question how can you earn bitcoins in this bear market? wed like to introduce you a new type trading product called future trading contract. bull (uptrend) or bear (downtrend) market. you can choose to buy long (predicting bitcoin price up) or put short (predicting bitcoin price down). in addition, bitcoin future always have leverage added, which mean that with a limited amount of bitcoin, you can profit much more by leveraging your bitcoin future position. for example, suppose you buy 100 bitcoins by 4000 dollar for each, your total investment is 400000 dollars. bitcoin price fell to 3000 dollars, you will lose 100000 dollars. however, you can easily earn by using future trading contract with 100x leverage. let u follow the previous example, you decide to use your 100 bitcoins to put short in the price of 4000 by future contract. when the price fall to 3000 dollars, you can earn 33 bitcoins. now you have totally 133 bitcoins, which value 400000 dollars, your real value remains the same because of the rise by the bitcoin you owned. magically, you can limit your investment with a small amount of bitcoin to earn the same about profit, followed by the previous case, you possibly hardly to invest all your 100 bitcoins because of the high risk. you can use 1 unit of bitcoin to put short in the price of 4000 by future contract. when the bitcoin price fall to 3000 dollars, you can also earn 33 bitcoins which are the same profit compared to the previous case without leverage. however, a you see, you only need to invest 1 bitcoin. what is magic! let do some calculation to make the profit more understandable. your total investment: 100 bitcoins (400000 dollar) in the price of 4000 dollars. when the bitcoin price fall to 3000 dollar, your total investment value: 100 bitcoins*4000 dollar 100 bitcoins*(4000 3000) dollar=300000 dollar. although the unit of bitcoins are same, the total value of your bitcoins is a loss for 100000 dollars. your total investment: 1 bitcoin (4000 dollars) in the price of 4000 dollars. when the price fall to 3000, your total investment value: 1 bitcoins * 100x leverage=100 bitcoins. although the value of the bitcoin falls, the amount of your bitcoins rises, your total investment value rises. please note:compared to these two cases, the first example, you invest 100 bitcoins (400000 dollar), but in the second example, you invest only 1 bitcoin (4000 dollars) with 100 time leverage. in other words, the leverage can help you to reduces your risk in the investment. in conclusion, if you are familiar with future contract and leverage, you may have a big chance to earn money even the bitcoin price fall down. the future contract, (especially the put/sell contract mechanism) and leverage is two sharpen weapon which you use to fight for profit. bexplus is a relative newbitcoin future exchangewhich provides a perpetual contract of btc, ethereum and ltc future with 100x leverage. headquartered at hong kong, it ha established office in united states, russia, brazil, australia, india, and nigeria. it support 15 language and cover 26 country and region worldwide. you can easily to trade in bexplus with an e mail address. to deposit btc in the bexplus account, you can earn 100% btc bonus, which can also be used to trade future contracts. the more deposit, the more bonus you will get. you ...
#  'bitcoin today is around $60 billion so i think it ha the opportunity to replace gold a the dominant store of value in which case it can go up a hundredfold from where it is today, say lou kerner, a founding partner of crypto oracle strategic. this is just a better store of value and if the world come around to sharing that view and i think were on that path, then we are easily over 100,000 in three or four year i think in bitcoin. what it evolved into today is a stored value. today, the main stored value is gold, it a $9 trillion thing. bitcoin today is around $60 billion so i think it ha the opportunity to replace gold a the dominant store of value in which case it can go up a hundredfold from where it is today. even if it becomes a strong second it can go a long way. it just a better way to store your value. i think we just got ahead of ourselves. thats what happened. i have a word that i use to describe the tendency of market to become bubble and the word i use to describe that is capitalism. bitcoin is kind of the early leader, kind of like the yahoo of it day. while it a massive thing it not the thing. if this is a thing and we really believe that in 20 year it will have created trillion of dollar in value similar to how the internet has, then we are at the very beginning today and it going to be here (way up) in 20 years. thats my forecast. the great thing about making 20 year forecast is that nobody know you are going to be wrong for a long time. if you focus on where you are going to be in 20 year then all of this (up and down) is just noise. if this becomes a store of value, and we think it is well on the path gold ha had a 5,000 year run. it a great run. what else ha lasted 5,000 years? this is just a better store of value and if the world come around to sharing that view and i think were on that path, then we are easily over 100,000 in three or four year i think in bitcoin. if you take a look at the history of currency over time 100 percent of them up until 400 year ago went to zero. the truth is if you think about the dollar, it a ponzi scheme. it fine, this is how government work. nobody think we are ever going to pay back the debt that we have. we are never going to pay back $20 trillion in debt. by the way, there going to be more tomorrow and more the day after. the only way to maintain your purchasing power and the only thing that ha held up ha been gold. thats how you store your value. over time all currency degrade and eventually they all go to zero. today, $8 trillion is stored in gold, in value that people are saying i dont want to hold the dollar. it part of a diversified portfolio generally. silver is the second biggest store of value at about $50 billion and bitcoin today is $60 billion. so it really kind of take over second place from silver a a store of value. bitcoin started off to be a digital currency. it can still potentially become one but the problem a really the first iteration of a decentralized entity that achieved scale there not a functional governance. so bitcoin really struggle to evolve. it doesnt need to evolve to be a store of value, but it doe need to evolve to be a digital currency. we think that there will be digital currencies. we think that government are going to issue their own digital currencies. but they will obviously be pegged to their regular currency and they will degrade over time. we think that pure digital non government digital security where you know how many dollar or whatever it is are going to be (is better). the problem is nobody know how many dollar there are going to be tomorrow other than you know there are going to be more.',
#  "break below 1. the u. s. dollar vs. canadian dollar exchange rate (usd/cad) is trading at 1. u. s dollar strengthens on an improved outlook for u. s. from a technical point of view, our study suggest these gain are unlikely to hold much longer and will probably eventually be undone by another wave of selling. a pattern called a bear flag ha formed on the usd/cad chart which strongly suggests more downside for the pair in the near future. this particular example of a bear flag is textbook in outline. a break below the 1. ma. this is a conservative estimate a bear flag normally decline the same distance a the length of the flagpole extrapolated below the flag, which in this case would suggest a sell off to the lower 1. the location of the 200 day at 1. ma) in the 1. both the weekly 50 and 200 ma are situated in the mid 1. the weekly chart show the pair climbing steadily in an ascending channel and the bear flag forming within the channel. despite the bullish trajectory of the channel, there is a risk the exchange rate could break out of the base of the channel and trigger a much deeper sell off. a move below 1. momentum is also strikingly bearish on the weekly chart and support the forecast. usd/cad ha declined due to a fall in the u. s. dollar a a result of a switch in interest rate expectation one of the primary driver of foreign exchange. interest rate had been expected to rise significantly in 2019, but then a steep sell off in the u. s. now the market expects interest rate to remain flat in 2019 and since the dollar tends to track rate it is expected to trade with a subdued tone too. initially, the more subdued outlook for the u. s. canada, which benefited the canadian dollar and probably contributed to the steep sell off during the flagpole section of the pattern. however, so tethered to is the canadian economy to the fortune of the american economy that the perceived slowdown across the border began to contaminate the outlook for canada and after it most recent meeting the bank of canada also switched policy and adopted a neutral stance in relation to interest rates, which probably contributed to the technical consolidation during the formation of the flag square. time to move your money? get 3 5% more currency than your bank would offer by using the service of foreign exchange specialist at rationalfx. a specialist broker can deliver you an exchange rate closer to the real market rate, thereby saving you substantial quantity of currency. the pound's outlook against the canadian dollar ha shown a material improvement of late, and on this basis we could expect further gains. but, we are wary of volatility around tuesday's key brexit vote in the british parliament and an unexpectedly positive canadian gdp data release due out mid week. the canadian dollar gave up some of it earlier gain wednesday after official data revealed a steep slump in retail spending during the black friday month of november, which implies and economic contraction for that month and add to a growing body of evidence suggesting growth ha decelerated more broadly of late. the canadian dollar is set to rise against the u. s. dollar, euro and pound this year, according to the latest forecast from bmo capital markets, a oil price stabilise and the bank of canada lift it interest rate on three occassions. our study of usd/cad suggest recent gain are unlikely to hold much longer and will probably eventually be undone by another wave of selling. bank rate according to latest imti data. rationalfx dealing desk quotation. all content pound sterling live 2013 2018. the news and information contained on this site is by no mean investment advice. we intend to merely bring together and collate the latest view and news pertaining to the currency market subsequent decision making is done so independently of this website. all quoted exchange rate are indicative. we cannot guarantee 100% accuracy owing to the highly volatile and liquid nature of this market.",
#  'stablecoins come into the picture at a time when the massive fluctuation of digital asset impedes their application. a recent report called stablecoins: the newbank account ha revealed an optimistic time ahead for these stablecoins. the digital coin pegged with fiat or gold have contributed to the disruption of traditional payment space. the research suggests that the total market opportunity for stablecoinsexceeds $18 trillion while that of bitcoin [btc] stand at somewhere around 15 trillion. the colossal difference between stablecoinand conventional banking institution is that it provides a payment processing channel that is time and cost efficient. a significant edge that pegged currency have over traditional banking account is that anyone can access and transferfunds in real time with no transactional fee involved. the processing fee and time in term of stablecoin is nil. on the other hand, the processing time for u domestic transfer take around 24 hour at a fee of $20 per transaction and cross border payment account for a processing time of 48 hour at a fee of $40 per transaction. tether [usdt] ha been the stablecoin that ha been around for the longest time, since it inception in 2014, and it continues to dwarf the newer stablecoins in the market. the research exhibited the number which backed tether dominance over recentplayers [like trueusd, paxos standard token, gemini token, among others] in the space. the entire stablecoin space valuation despite the entry of new player in 2018 stood at more than $700 million while the traded volume totaled at more than $11. tether [usdt] had an issued value of $2,036 million. the cumulative daily trading volume of the oldest stablecoinhad been registered at $ 2,950 million and the trading volume for the year 2018 totaled at $1,080 billion. the report also mentioned a whopping a $600 trillion transfer volume of stablecoinsin 2018 via domestic bank transfer, out of which tether [usdt] scooped a significant$109 billion volume, a 624% increase in it share from it $15 billion volume the year before. despite being a critical contender, stablecoins have a long way to go with respect to it offering to compete with traditional banking establishment in a mainstream scenario.',
#  'binance is living up to it promise to move further into the crypto fiat trading market, today opening the door at a new exchange for the european market. resident customer will be able to trade btc and ethereum with british pound (gbp) and euro (eur) on the platform based in the channel island jurisdiction of jersey. wei zhou said it wa binances strategy to seek on and off ramps between cryptocurrency and the fiat system. the exchange ha a goal to sign up a billion user or more, and launched it first fiat exchange in uganda in late 2018. it also plan to open fiat trading in asia when possible. in today announcement, zhou repeated his claim that cryptocurrency adoption and use is it main motive. impending financial confusion over the u. k. european union (a. brexit) could provide an opportunity to move into cryptos should the gbp or eur prove unreliable amid the transition. jersey ha in place an existing legal and regulatory framework for cryptocurrency into which binance jersey easily fits. jersey is an undisputed pioneer in blockchain development leveraged by this strong framework and talent pool. binance jersey hope to increase jersey competitive advantage in banking from other jurisdiction competing for cryptocurrency related business a the island cryptocurrency regulation allows. jersey is the largest of the channel islands, small autonomous jurisdiction in the english channel off the coast of france. though considered crown dependency they are not officially part of the u. k. e. u. it promise incentive and support in the form of connectivity, favorable condition for investment, and regulatory sandbox measure that allow startup to experiment on a small scale outside many of the law that impact larger companies. binance formed a partnership with digital jersey in june 2018 and ha since been building banking relationship and seeking local talent. trading pair for the new exchange include btc/gbp, ethereum/gbp, btc/eur and ethereum/eur. binance will enable user to trade on the gbp and eur fiat exchange immediately upon completing the account kyc verification process on www. is binances growth strategy going to work? what do you think? let u know in the comments. jon southurst is a senior editor at bitsonline. he is based mainly in tokyo, and is interested in the role asian economy play in developing cryptocurrency and blockchain. china govt tightens blockchain rules, but its. the unique consensus mechanism of decredis this. bakkt acquisition: backend buyup to boost crypto. the unique consensus mechanism of decredis this true decentralization?']

# %%
len(Results_Dict['Category 1'][2])
# Out:
# 10

# %% [markdown]
# Q4: Based on the Q1 and Q2, please rank the top-10 document order with the content from the representative article toward each group.
#
# Ans: If now we want to know the top-10 document order with the content from the representative article toward Category 1, we could execute the code as follows:

# %%
Results_Dict['Category 1'][3]
# Out:
# ["born with the idea of having a stable cryptocurrency that can be used a digital dollars, tether is a cryptocurrency with a value meant to mirror the value the u. s. tether is a cryptocurrency with token issued by tether limited, and claim to be backed up by u. s. tether platform. tether which come with the trading abbreviation usdt, belongs to a group of cryptocurrency, with which one can transfer amount in real time and exchange them with other currencies. tether is supported by several blockchain platform such a kraken and bitfinex. it is also one of the stable coin because it act a an alternative to u. s. it act a a stable dollar for many exchanges, and is also one of the most stable option available. unlike other cryptocurrency, tether is supposed to be backed by dollar kept in reserve in a 1:1 ratio, which is a big selling point, and a big problem in the untethered and decentralized crypto arena. although it claim to trade at $1 on all exchanges, the actual price seems to fluctuate a little. it all started with j. r. willett publishing a paper in 2012 stating the possibility of new currency on top of the bitcoin protocol. tether cryptocurrency one of the original member of mastercoin foundation, brock pierce, would become a co founder of tether. craig sellars, cto of mastercoin, would also become one of the co founders of tether. in july 2014, they launched realcoin, which wa the precursor to tether. after releasing the first coin in october 2014, one of the founders, reeve collins announced in november 2014, that the project wa being renamed to tether. in early 2015, bitfinex enabled trading with tether on their platform. while tether and bitfinex have always stated that they are separate companies, the paradise paper in 2017, leaked that bitfinex official philip potter and giancarlo devasini are responsible for helping the setup of a the company tether holding limited in the british virgin island in 2014. later, a spokesperson for bitfinex and tether said that the ceo of both firm is jan ludovicus van der velde. initially, tether had been processing u dollar transaction through taiwanese banks, which transferred the money through the well fargo bank which allowed the fund to move outside taiwan. in april 2017, according to tether, these international transfer were blocked. in 2017, the omni foundation and charlie lee announced that tether would issue on the omni layer of cryptocurrency. united state dollar and euro on the ethereum blockchain. tether later gave the confirmation that the ethereum token were issued. at present, there exists a total of four distinct tether token namely, the united state dollar tether and the euro tether present on bitcoin's omni layer, the united state dollar tether and the euro tether present a an erc 20 token. a of september 2018, the number of tether grew to about $2. by the summer of 2018, it accounted for up to 80% of bitcoin volume. in october 2018, the price of tether fell to $0. bitfinex exchanged tether for bitcoin, driving it price up. tether is a digital to fiat currency and it can be easily traded at bitfinex, kraken, shapeshift and many other exchange easily. you can easily convert real world u dollar (usd), euro (eur), and japanese yen (jpy), to their equivalent digital token or crypto tether usd, tether eur, and tether jpy and then use them in any digital platform that allows cryptocurrency and support tether. unlike bitcoin and other cryptos, the exchange rate is stable always at 1:1 for all fiat currency that it supports, which is a good thing regardless of whether you want to convert your bank real world money into crypto or otherwise, since tether token can also be redeemed for cash. sending tether to tether wallet ha always been free. the company also offer decentralized exchange, browser based, open source, wallet encryption. but before using tether, there are a few thing that you should know and understand. buried deep within the term of service of tether agreement d ...
#  'stablecoins act a a cryptocurrency tied to the price of national currency. in this, we explore the fundamental of a fiat backed stablecoin. cryptocurrency are praised for paving the way for decentralized, peer to peer method of tender and blockchain based currency are promising to take electronic money to the next level. there are several obstacle which are blocking the path to widespreadadoptionand might hinder the support that national government have regarding cryptocurrency. one of the biggest issue that token face is the extreme volatility of market capitalization and price swings. a stablecoin is a cryptocurrency token which ha it value pegged at a 1:1 to a stable asset, such a gold or a fiat currency like the u dollar. the fundamental point of a stablecoin is to hold it pegged value, despite the twist and turn of volatility that the cryptocurrency market face otherwise. while cryptocurrency backed and non collateralized stablecoins exist and are gaining traction, the most common and by far the most well known stablecoins are the fiat backed cryptocurrency; pegged to a national currency. a the name implies, fiat stablecoins are token which are associated with the value of a particular fiat currency. usually,these token are based on the u dollar and hold their value fixed at a 1:1 ratio. arguably the most well known stablecoin and at the time of writing one of the top ten cryptocurrency, tether is pegged to the u dollar. daily, tether see an average trading volume of $4 billion usd, making it the largest stablecoin in daily volume and market cap. tether ha a close association with cryptocurrency exchange bitfinex, sharing the same cep. tether ha gained a lot of criticism owing to it lack of transparency in it methodology, a well a the lack of any official auditing of the token. this, in addition to centralization issue that arise despite the decentralized nature of cryptocurrency. usdt tokens. however, there are some controversy surrounding tether a there is a lack of transparency in whether usdt is fully backed by the equivalent fiat reserves. while tether claim that their usd fiat reserve are sufficient to back all the issued usdt token on a 1 to 1 basis, many critic have been challenging this claim. many critic believe tether company ha issued more usdt token than it dollar reserve in it bank account. they also claim that tether management team have been artificially pumping bitcoin price with all the newly printed tethers. where tether get criticized for it lack of transparency and centralization, trueusd get praise for being open in their legal operations. the trueusd team ha also set up an escrow account to which they have no access for user to exchange u dollar into tusd tokens. this alleviates claim of centralization and the smart contract in place also help in maintaining the 1 u dollar: 1 tusd ratio. the paxos standard wa founded in 2012 by paxos trust company. the stablecoin exists on ethereums blockchain a an erc 20 token and can be stored in any erc 20 compatible wallet. a paxos is pegged to the u dollar, pax token can only exist in circulation while corresponding dollar are held in reserve. if the pax token are exchanged to dollars, the corresponding stablecoins are destroyed to avoid any fluctuation in price. the gemini dollar is backed and founded by the winklevoss twin cryptocurrency gemini. the token is therefore issued by gemini trust company, llc, a new york trust company and ha been allowed and is regulated by the new yorkstate department of financial services. the gemini dollar also exists a an erc 20 token and one token is redeemable for $ 1 usd on the gemini exchange. start trading cryptocurrency with coindirect. internet writer looking to find the right piece. also present thing on radio and happens to be a chip off the old blockchain. coininsider is the authority on blockchain; providing breaking news bulletins, incisive opinion, market analysis, and regulatory updates.',
#  'stablecoins come into the picture at a time when the massive fluctuation of digital asset impedes their application. a recent report called stablecoins: the newbank account ha revealed an optimistic time ahead for these stablecoins. the digital coin pegged with fiat or gold have contributed to the disruption of traditional payment space. the research suggests that the total market opportunity for stablecoinsexceeds $18 trillion while that of bitcoin [btc] stand at somewhere around 15 trillion. the colossal difference between stablecoinand conventional banking institution is that it provides a payment processing channel that is time and cost efficient. a significant edge that pegged currency have over traditional banking account is that anyone can access and transferfunds in real time with no transactional fee involved. the processing fee and time in term of stablecoin is nil. on the other hand, the processing time for u domestic transfer take around 24 hour at a fee of $20 per transaction and cross border payment account for a processing time of 48 hour at a fee of $40 per transaction. tether [usdt] ha been the stablecoin that ha been around for the longest time, since it inception in 2014, and it continues to dwarf the newer stablecoins in the market. the research exhibited the number which backed tether dominance over recentplayers [like trueusd, paxos standard token, gemini token, among others] in the space. the entire stablecoin space valuation despite the entry of new player in 2018 stood at more than $700 million while the traded volume totaled at more than $11. tether [usdt] had an issued value of $2,036 million. the cumulative daily trading volume of the oldest stablecoinhad been registered at $ 2,950 million and the trading volume for the year 2018 totaled at $1,080 billion. the report also mentioned a whopping a $600 trillion transfer volume of stablecoinsin 2018 via domestic bank transfer, out of which tether [usdt] scooped a significant$109 billion volume, a 624% increase in it share from it $15 billion volume the year before. despite being a critical contender, stablecoins have a long way to go with respect to it offering to compete with traditional banking establishment in a mainstream scenario.',
#  "bloomberg) the contest is heating up to gain marketshare in one of the most closely watched product in the world of cryptocurrency: physically delivered bitcoin futures. while the owner of the new york stock exchange is expected to start offering such contract shortly and chicago's eris exchange llc plan to follow, the firm that say it wa first to market ha spun off from it previous owner and will provide the derivative on some of the largest digital coin to asian retail investor beginning next month. started last year a coinfloorex, then a unit of the u. k. bitcoin exchange coinfloor, the platform will now be called coin future and lending exchange, or coinflex. the venture is owned by a consortium including famed early crypto advocate roger ver andtrading technology international inc. chicago, which develops trading software for broker and money managers. coinfloor, the u. k. bitcoin exchange, will also retain an equity stake. mark lamb, a co founder of coinfloor, will be the chief executive officer of the new business based in hong kong. coinflex, will offer future contract for bitcoin, bitcoin cash and ethereum that can be leveraged up to 20 times. the exchange will likely draw comparison with, and seek to take business from, bitmex, one of the largest crypto trading platforms, which also ha a sizable presence in hong kong and wa co founded by former citigroup inc. arthur hayes. bitmex offer leverage of up to 100 time on some of it contracts. still a key distinguishing factor in coinflexs favor is that all future traded on the exchange will be physically delivered, lamb said in an interview. that mean when the contract expire, owner will be given the underlying cryptocurrency instead of a cash payment. thats an important distinction in the largely unregulated market where bitcoin and other digital coin currently trade a some big player say the process for settling a contract in cash could be manipulated. crypto derivative could become an order of magnitude larger than spot market and the main thing thats holding back that growth is the lack of physical delivery, said lamb. volume are reduced because of a problem of trust when it come to cash settled trades. currently the daily volume of trading in the underlying crypto market is approximately equal to that in derivatives, at around $3 billion, said lamb. in other markets, future volume can be 20 time larger, suggesting there is plenty of room for growth in contract tied to digital assets, he said. coinflex will have to compete with intercontinental exchange inc. nyse, which plan to introduce a physically delivered future contract a part of it crypto venture called bakkt. chicago based derivative market eris exchange is opening a market that will also feature physically delivered contract on some of the largest tokens. a part of it future offering, coinflex will make a big bet on tether, one of the market most controversial token that ha been dogged by speculation about whether it token are backed by the amount of dollar it founder have claimed. a bloomberg news report last month that offered the clearest indication yet of tether finance suggested such fear may be unfounded. coinflexs contract will trade against tether, a crypto that is pegged to the dollar. that mean at expiry, party who are short will deliver bitcoin and receive tether, while for longs it will be the other way round. this mechanism is fundamentally different to that for cash settled contract at rival exchange where gain and loss are paid out either entirely in dollar or bitcoin, a a proxy for cash, based on an index price, he said. the index level is based on a collation of price for the underlying digital asset on a number of spot exchanges. in crypto markets, these contract are susceptible to a form of manipulation known a banging the close where trader aggressively buy or sell asset on relevant exchange during the time of a future expiry in order to influence the settlement price, lamb said. coinflex ...
#  'coinflex plan to debut physically settled bitcoin future to the asian market beginning in february 2019. the platform is a consortium with participant such a roger ver (bitcoin. ceo), b2c2, trading technologies, and alameda research among others. coinflex plan to offer future contract for bitcoin, bitcoin cash, and ethereum. like bakkt (owned by intercontinental exchange), coinflexs offering are physically backed contracts. for lamb, there is great potential for expansion within the cryptocurrency future market. according to the coinflex ceo, the crypto future arena should be able to grow to 20 time the size of the spot trading market a is the case for other asset classes. presently, both market handle approximately the same volume of daily transactions. one unique detail of the coinflex offering is that contract will trade against tether (usdt), the most popular stablecoin, which is pegged against the u. s. apart from tether, coinflex also plan to launch a contract that will trade opposite circle usd coin; another stablecoin. at the expiration of the contracts, trader who hold long position will receive bitcoin, ethereum, or bitcoin cash while trader who hold short position will receive usdt depending on the performance of the contract. the reason for this is because it is incorporated offshore, allowing the platform to offer it product to a more global market except for highly regulated market like the u. s. u. k. when pressed about competition from the like of bakkt, cme, and cboe, lamb highlighted the fact that u. s. bitcoin future trading account for only a tiny portion of the market. the primary reason for this disparity stem from the fact that market like the u. s. thus u. s. asia. the coinflex chief belief btc future trading doesnt require the same level of stringent regulation like the spot trading market. where the latter offer leverage of up to 100 time on specific contracts, coinflex cap it offering at a leverage of 20 times. let u know your thought in the comment below.',
#  'a project called coincodecap (c3) track the development activity of dozen of crypto projects, and according to their data, the top 10 project by market capitalization of their token are far from the most actively developed. in this market, it necessary that you monitor the technological aspect of the crypto, because today investor consciousness will create something that can help human for a long time. if we didnt follow the tech progress and go with the market fud, then you will have an inevitable market crash and people will lose trust in the market a well a in technology, and we dont want it because no one can deny the enormous potential of blockchain, writes the team behind c3 in a blog post. the tech development of a project in the case of c3 is based on the amount of work done that wa also published on github, a web based hosting service that is most often used for code. the calculation take into account data such a commits (individual change on a file), repository (the most basic element of github, best imagined a a folder), fork (a personal copy of another user repository that life on your account, which let you freely make change to a project without affecting the original), etc. however, when looking at the activity during the last 3 months, 0x top the ranking. tether is unranked a it is not an actively developed cryptocurrency, but a smart contract which issue and destroys token based on investments. the project ha ranked a total of 1,134 cryptocurrency, including many with no commits at all.',
#  'the ethereum price (ethereum/usd) ha edged lower on friday, despite seeing a strong boost that lifted it well above the $150 mark in early trading. the second largest digital currency on the market suffered significant loss yesterday, a it price spent the majority of the session on a downward trajectory. the coin tumbled to an intraday low of $147. still this wa well below ethereums opening level of $155. ethereum enjoyed strong positive action in today early trading, which allowed it to return above the $150 mark. however, after hitting an intraday high of $156. ethereums decline intensified in recent trading, when the coin one again dipped below the $150 level. ethereums decline appears to be part of a larger downtrend observed across the broader crypto market. all top ten digital currency are posting loss over the past 24 hours, including the leading cryptocurrency bitcoin (btc) which dropped below the $3,800 mark in recent trading. bitcoin cash (bch) and it offshoot bitcoin sv (bsv) are the worst performing top 10 coin over the 24 hour period, having lost about 4. meanwhile, ethereum ha shown greater resilience than all of it major rivals, with the exception of the stablecoin tether (udst). in today trading, the ethereum price stood at $148. gmt. the digital coin ha lost nearly 1% of it value in the past 24 hours, according to data from digital currency tracker coinmarketcap. the coin total market cap currently stand at just over $15. receive free, real time email notification with breaking news and commentary.',
#  "nevertheless, both the year are now behind u and a new year ha just begun. with this new year, come new hope and new expectations. now that we're a week into 2019 and all the hype and festivity around the new year have slowed down, here a list of the top 10 expectation that every cryptocurrency enthusiast ha from the market over the next three hundred and fifty eight days. the following are the top 10 expectation from the cryptocurrency markets. please note that they are not listed in any order of importance, a we consider all of them to be equally important for the growth of crypto market in the year to follow. one of the biggest hope from the year is that 2019 will be the year we get to see the bull in action once again, helping the price of bitcoin recover. the currency reached an all time high of $19,700 in late 2017. from there, it fell to a low of $3,190 in december 2018. over the course of a year, bitcoin ha gone through a major slowdown. however now that we are in 2019, there an anticipation in the market that now that the price have tanked, large scale buying is about to begin any time now. this is bound to help the price grow a growth attracts growth! while a number of investor have left the markets, crypto bigwig such a mike novogratz and brian armstrong continue to remain optimistic about the state of crypto market in 2019. another major expectation from 2019 is that it will be a safer year for cryptocurrency market compared to the past few years. coincheck hack resulted in $530 million being wiped out of the cryptocurrency markets. there were attack on bitgrail, zaif, bithumb and a number of other cryptocurrency exchange over the year resulting in hundred of million of dollar being lost over the course of 2018. in addition to security of the cryptocurrency exchanges, in 2019, the crypto market should also see a decline in scam the like of which are prevalent on social medium asking people to send cryptocurrency to an address in exchange for a large amount being sent over to them. then there are ponzi scheme and pump and dump scams, cryptojacking and a number of other crypto related threat which need to be quashed over the year. with awareness level rising, it is anticipated that in 2019, crypto related crime would see a decline. perhaps the biggest expectation this year is that of regulatory clarity. government across the world have begun to take a serious notice of the crypto economy and have begun to set up committee and body which have been coming out with regulation regarding cryptocurrency. however, the concept seems rather alien to many nation and committee spent a major part of the past few year studying cryptocurrency and the underlying technology. it is expected that in the year 2019, these governmental body would come out with better regulatory policy surrounding cryptocurrency. in addition to the legal status and regulations, taxation seems to be another pressing issue around the world. government around the world have finally begun to get the hang of how to tax cryptocurrency and under what head would they be taxed. it is expected that in 2019, government body would bring out more clarity with regard to how they plan to tax cryptocurrency. lesser ico scams! fake initial coin offering (icos) and ico scam boomed in late 2017 and the first half of 2018 a the cryptocurrency market soared. this led to million of dollar being scammed from unsuspecting investor who bought into the concept pitched by these scammers. sometimes, these ico scam were in the name of investment scheme promising guaranteed returns. the security and exchange commission of the united state (sec), a well a a number of other watchdog authority from across the world have been keeping an eye out for such scam and have been sending them cease and desist notice over the years. the u sec even came up with a mock website showcasing how ico scam website look like and how to stay safe from ico scams. these ico scam actually hurt the credibilit ...
#  'the market monotony continues and thing are still flat in crypto land this slow sunday. none of the major cryptocurrency have moved since yesterday leaving total market capitalization lulling around $120 billion where it ha been all week. bitcoin showed a glimmer of hope when it spiked to an intraday high of $3,650 but soon dumped back below this solid barrier of resistance where it currently trades. since last sunday dump btc ha done very little being stuck at $3,600 for a week now. ethereum ha dipped again dropping almost a percent back to $115 and xrp ha done the same dragging it below $0. a with bitcoin there ha been no movement for these two for the past week a they gradually weaken in preparation for further losses. a 2% dump by bitcoin cash ha allowed eos to flip it into fourth by not moving. tether ha climbed to sixth by doing nothing but today big mover is tron which ha jumped both cryptocurrency and stellar with a 12% pump. trx is now in seventh spot at $0. the imminent btt token sale launch tomorrow and a boost by wei rating ha given tron the lift above both ltc and xlm at the time of writing. in the top twenty only binance coin is moving with 4% added a it creep up on cardano in eleventh. all of the others have fallen back with nem and neo dropping over 2% each. holo is today top one hundred top performer with a 17% fomo drive at the moment. tron is second and these are the only two altcoins making double digit gain at the time of writing. loopring and augur are both dropping around 8% right now but there are no major dump going on at the moment. total market capitalization had a little boost but ha fallen back again over the past 24 hours. it is currently at $119 billion and still looking very weak with huge level of resistance facing bitcoin and it brethren. since last sunday $5 billion dump market have done nothing but consolidate at this level, the tedium continues. market wrap is a section that take a daily look at the top 20 cryptocurrency during the current trading session and analysis the best performing ones, looking for trend and possible fundamentals. global service and component marketplace. boost your time to orbit!',
#  'one and a half year back tether wa the dominant dollar pegged cryptocurrency. now, there are so many dollar pegged cryptocurrency such a true usd, dai, steem dollars, white standard, etc. soon, we may have the yen, aud and won pegged cryptocurrency. the list will soon have a new addition from novem, a liechtenstein based blockchain startup. the major difference is that the cryptocurrency will be pegged to gold that will be held in germany. trader will be able to buy and sell ounce of gold quite easily using their crypto wallet. the company ha mentioned that stablecoin, dubbed a 999. the developer behind the crypto are planning to send a certificate when a trader purchase 999. novem is a better way to buy gold, with all purchase verified by third parties at the time of purchase, secure storage with third party auditing, and at the time of sale. the differentiation from other gold backed coin is 100% liquidity and old economy precious metal industry certifications. the spokesperson further said at this point, over $1,035,000 in nvm [999. there ha been significant interest in the project in both the precious metal and blockchain communities. the novem team ha further stated that the gold will be stored in their vault in germany. however, no evidence ha been presented to prove the legitimacy of the crypto so far. by the start of 2019, over 30 kg of gold, valued at nearly $1. loomis and subject to regular third party auditing. the quantity of securely stored physical gold is projected to more than double with a commensurate number of nnn gold token minted by the time of public sale, which begin in 3 weeks. one of the major concern investor may have is that the token is running on unpopular neo blockchain. that is in addition to the lack of proof regarding the availability of the crypto currency. wolfgang schmid and mario schober, who are former trader of precious metals. andreas kalte, experienced precious metal trader schmid and schober, and kalte, who ha experience in scaling walls.']

# %%
len(Results_Dict['Category 1'][3])
# Out:
# 10

# %% [markdown]
# Q5: Please combine both methods you applied in the Q3 and Q4 to output the similar format result.
#
# Ans: If now we want to know the top-10 document order toward Category 1 based on the methods we applied in the Q3 and Q4, we could execute the code as follows:

# %%
Results_Dict['Category 1'][4]
# Out:
# ["born with the idea of having a stable cryptocurrency that can be used a digital dollars, tether is a cryptocurrency with a value meant to mirror the value the u. s. tether is a cryptocurrency with token issued by tether limited, and claim to be backed up by u. s. tether platform. tether which come with the trading abbreviation usdt, belongs to a group of cryptocurrency, with which one can transfer amount in real time and exchange them with other currencies. tether is supported by several blockchain platform such a kraken and bitfinex. it is also one of the stable coin because it act a an alternative to u. s. it act a a stable dollar for many exchanges, and is also one of the most stable option available. unlike other cryptocurrency, tether is supposed to be backed by dollar kept in reserve in a 1:1 ratio, which is a big selling point, and a big problem in the untethered and decentralized crypto arena. although it claim to trade at $1 on all exchanges, the actual price seems to fluctuate a little. it all started with j. r. willett publishing a paper in 2012 stating the possibility of new currency on top of the bitcoin protocol. tether cryptocurrency one of the original member of mastercoin foundation, brock pierce, would become a co founder of tether. craig sellars, cto of mastercoin, would also become one of the co founders of tether. in july 2014, they launched realcoin, which wa the precursor to tether. after releasing the first coin in october 2014, one of the founders, reeve collins announced in november 2014, that the project wa being renamed to tether. in early 2015, bitfinex enabled trading with tether on their platform. while tether and bitfinex have always stated that they are separate companies, the paradise paper in 2017, leaked that bitfinex official philip potter and giancarlo devasini are responsible for helping the setup of a the company tether holding limited in the british virgin island in 2014. later, a spokesperson for bitfinex and tether said that the ceo of both firm is jan ludovicus van der velde. initially, tether had been processing u dollar transaction through taiwanese banks, which transferred the money through the well fargo bank which allowed the fund to move outside taiwan. in april 2017, according to tether, these international transfer were blocked. in 2017, the omni foundation and charlie lee announced that tether would issue on the omni layer of cryptocurrency. united state dollar and euro on the ethereum blockchain. tether later gave the confirmation that the ethereum token were issued. at present, there exists a total of four distinct tether token namely, the united state dollar tether and the euro tether present on bitcoin's omni layer, the united state dollar tether and the euro tether present a an erc 20 token. a of september 2018, the number of tether grew to about $2. by the summer of 2018, it accounted for up to 80% of bitcoin volume. in october 2018, the price of tether fell to $0. bitfinex exchanged tether for bitcoin, driving it price up. tether is a digital to fiat currency and it can be easily traded at bitfinex, kraken, shapeshift and many other exchange easily. you can easily convert real world u dollar (usd), euro (eur), and japanese yen (jpy), to their equivalent digital token or crypto tether usd, tether eur, and tether jpy and then use them in any digital platform that allows cryptocurrency and support tether. unlike bitcoin and other cryptos, the exchange rate is stable always at 1:1 for all fiat currency that it supports, which is a good thing regardless of whether you want to convert your bank real world money into crypto or otherwise, since tether token can also be redeemed for cash. sending tether to tether wallet ha always been free. the company also offer decentralized exchange, browser based, open source, wallet encryption. but before using tether, there are a few thing that you should know and understand. buried deep within the term of service of tether agreement d ...
#  'accell cables, a provider of adapters, cables, and power supplies, is launching a vr adapter which condenses a headset cable into a single usb c cable (for usb c equipped gpus) and extends the tether. the upcoming accell vr adapter accepts the hdmi and usb a cable from the rift or window vr headset and condenses them into a single usb c cable to be attached to any usb c equipped nvidiartx gpu, and also some nvidia laptop gpus with usb c compatibility. accell doe not note support for any amd gpus. for those running short on usb and video ports, the adapter could free up two commonly used port in favor of the le often used gpu usb c port. in addition to simplifying the connection to the pc, the accell vr adapter also ha an extra eight foot of cable, offering a lengthy extension over the default tether (which run around 13 feet). the adapter sport an oculus ready certification, marking it a officially compatible with the rift, though the company also say that it compatible with window vr headsets. vive is not mentioned a being supported, likely because it requires a separate power adapter. usb c. weve confirmed this is not the case; accell note that the adapter u a standard displayport alt mode of usb c rather than virtuallink which is a separate alt mode with a different configuration of data lanes. a the supported headset werent built with virtuallink in mind in the first place, the adapter not specifically using virtualink doesnt seem to make much of a difference.',
#  'the drone section at the consumer electronics show (ces) wa dominated by quadrotors and underwater drone. fig. aerial drone have been common at ce for years, but their aquatic brother have been a rarer sight until this year. uvifys quadrotor demo wa typical of the synchronized swarm at this year consumer electronics show. fig. the demo included autonomous a well a tethered, remote controlled drone. like flying drone, the underwater drone can perform inspection chore in addition to other photographic and exploration jobs. large pool of water were common in the drone section at ces. fig. k camera with 1080p streaming capabilities. it can record 4k video stream that are downloadable on recovery. it ha built in active stabilization common in quadrotors. the swappable battery provides four hour of operation. navatics mito sport a 4k camera and active stabilization. the mito is paired with a waterproof buoy with a wireless connection to a remote control unit. this can be up to five hundred meter from the buoy. fig. the cute drone come in different color and they have a gimbal mounted 4k camera. there a pair of 114 lumen light for operation in the dark. it u acoustic for remote control. a smartphone app can wirelessly control the unit when it is on top of the water. and a return to base feature that u built in gps work when the unit is on the surface. roboseas biki is a compact, autonomous underwater drone with a 4k camera. the biki u a caudal fin that can drive it to speed of 1. it u infrared sensor to avoid obstacle up to 30 cm away. the drone can dive to depth of 196 feet. fig. it articulated and driven by a caudal fin like the biki. it ha an omnidirectional obstacle avoidance system and internal space for add ons, providing a more professional platform than the biki. roboseas large robo shark swim like a shark but doe not bite. the robo shark can dive to three hundred meter and ha a 1. it can travel at speed up to 10 knot while being significantly quieter than propeller driven drone. the shell is made of sound absorbing materials. fig. the three vertical thruster are laid out in a triangle; all five are under control of the ai based system. the pitch angle can be set plus or minus 45 degree while moving. chasing innovation gladius mini ha a 4k camera and a one touch depth lock mode. the gladius mini fit into a backpack and ha a two hour runtime. it can dive to depth up to 330 feet, although it come with a 165 foot tether, and cruise at a fast 2 m/s. a one touch depth lock mode keep the unit at a particular depth. this is similar to many quadrotors with hover mode. fig. this essentially drop the electronics into an aquarium. it make changing board a bit more difficult since everything must be removed, but it doe work. the two phase immersive cooling system doesnt require pump like those used in conventional, conductive liquid cooling found in many high end gaming pcs. this isnt a test. it a system that can be purchased, a is the case with the other flying and aquatic drone mentioned here. gigabyte wa showing a liquid cooled server.',
#  'wearable technology is playing an increasingly important role in our lives. it seems like every week, a prominent tech company or revolutionary startup is ready to unleash their latest innovation into the world. classroom wearable are also becoming common a student learn through modern technology like gopro cameras, smartwatches, vr headset and more. all this ha the potential to drastically change the way we learn going forward. video project are a lot of fun for advanced learners, and adding a wearable camera into the mix can really change the way these project are approached. when a student is wearing a camera, they dont have to worry about setting up their equipment to get going. every moment is captured from the student own perspective, adding a personalized touch to the cinematic experience. gopros can be taken in and out of the classroom to complete projects, and theyre a whole lot easier to tote around than heavy digital recording equipment. incorporating activity tracking wristband into health project allows student to clearly see how the information theyre receiving tether into their everyday life. pedometer let them know how much they actually walk over the course of their day, and tracker that incorporate heart monitor can demonstrate how many calorie they naturally burn in their everyday lives. we could all use a little more interest when it come to keeping ourselves active and vital, and this is one of the easiest way to encourage student to take an interest in nutrition, fitness, and personal health. it can sometimes be difficult to get student to work independently, particularly if they arent self starters. smartwatches can keep everyone on the same schedule, and theyre a great tool for time management. student can send teacher message or information via the smartwatch, rather than waiting for an opportunity to speak with their busy educator. unfortunately, this also ha a flip side. smartphones are officially forbidden in exam hall but that doesnt mean they cant be smuggled in. many place also have specific rule about smartwatches, but again this is difficult to police. smartwatches are an excellent way to get a large group of people working a member of one productive team. this is exactly what most people want in a classroom environment. studying to the right music can help student stay focused on the task at hand. ambient background noise drowns out noisy distraction and keep learner calm. the only problem is that the same music wont work for everyone, and it may disturb lesson in neighboring rooms. bluetooth or wireless earbuds can allow a student to listen to study music that will work for them without affecting the people around them. the best thing about the wearable wireless technology is that it doesnt require the student phone to be out on the desk, which can potentially be a distraction. annoying wire wont get in the way of their work, either. you cant put a few dozen student on a plane and send them away to a historical location for a week, but you can replicate that experience without ever leaving the classroom. wearable vr goggles make this virtual field trip feel incredibly immersive. vr glass are a one time investment that can be used over and over again in the classroom, allowing student to experience thing they may not have otherwise been able to do. a wearable tech becomes more and more accessible, the landscape will continue to shift. the quality of education will improve, and the cost of device will inevitably decrease. student will be dealing with tech innovation for the duration of their lives, and it never too early to get them started with modern technology. like this article?',
#  'a project called coincodecap (c3) track the development activity of dozen of crypto projects, and according to their data, the top 10 project by market capitalization of their token are far from the most actively developed. in this market, it necessary that you monitor the technological aspect of the crypto, because today investor consciousness will create something that can help human for a long time. if we didnt follow the tech progress and go with the market fud, then you will have an inevitable market crash and people will lose trust in the market a well a in technology, and we dont want it because no one can deny the enormous potential of blockchain, writes the team behind c3 in a blog post. the tech development of a project in the case of c3 is based on the amount of work done that wa also published on github, a web based hosting service that is most often used for code. the calculation take into account data such a commits (individual change on a file), repository (the most basic element of github, best imagined a a folder), fork (a personal copy of another user repository that life on your account, which let you freely make change to a project without affecting the original), etc. however, when looking at the activity during the last 3 months, 0x top the ranking. tether is unranked a it is not an actively developed cryptocurrency, but a smart contract which issue and destroys token based on investments. the project ha ranked a total of 1,134 cryptocurrency, including many with no commits at all.',
#  'having launched it first vr headset in late 2017, alongside a handful of similar headset a part of microsofts window mixed reality platform, hp is preparing to take it next step with the launch of a new headset that diverges from the pack. it wa a seemingly fitting dayunusually dreary weather for california bay areato find myself in the basement of hp palo alto headquarters, safe from the wind and rain. after being led through secure doors, down an elevator, and along a maze of white hallways, i found myself inside a windowless bunker of a room: hp vr lab, im told. inside, past a row of computer with various consumer headset attached, i see two identical laptop sitting on a table off to the side. theyre powered up, with a long tether leading to a headset sitting in front of each. the first i recognize: samsungs recently launched odyssey+. the second easily couldve been mistaken for a rift at first glance, but upon closer inspection would prove to be something much different. microsoft launched it window mixed reality platform back in late 2017 alongside asalvo of vr headset from partner company (hp, acer, dell, lenovo, and samsung) which work with the platform. among that initial set of headsets, all but samsungs wa built to nearly identical specifications, apparently based around a reference design primarily developed by microsoft. that left little to differentiate the launchheadsets (other than samsungs) beyond aesthetics. this time around, hp is owning the design of it next gen headset from the ground up. it still a window mixed reality headsetwhich mean it retains the same quality inside out tracking and ease of setup which the platform is known for (thanks to not needing any external trackers)but beyond that, hp ha crafted a significant departure from it first headset. copper, a itscodenamed, ha a distinct rift like look to it; a slim, top strap design with sleek headphone attached to the headband. upon closer inspection, the rear of the headset see the top and side strap culminate in a circular structure (designed to cup the back of your head), while the front is encompassed by a heathered material into which the front facing camera are embedded. i wasnt allowed to take any photosafter all, hp ha yet to officially announce the headset; the company would only share a single untextured rendering. but the headset i saw already looked and felt nearly market ready, despite still being under wraps. thats because the device i tried is the very first tooled prototype, said john ludwig, product manager for vr at hp, which mean the company is already well on it way to doing production run of copper. ludwig, who ha been closely involved with the development of the headset, walked me through a demo where i strolled around a real time pre visualization of an architectural design. confident in the clarity id see through copper lenses, he offered up the odyssey+as a side by side comparison (currently the highest re wmr headset on the market at 1,440 1,600 per eye). indeed, copper clarity blew it away. thats no doubt primarily driven by copper 2,160 2,160 (per eye) displays, which have more than twice the number of pixel a the odyssey+, and more than three and a half time a many pixel a first gen headset like the rift. odyssey+. and while the odyssey+ u a diffuser on the screen (which sacrifice some sharpness in an effort to hide the screen door effect), copper hardly ha a need for a diffuser a the pixel dense rgb stripe display make the screen door effect vanishingly apparent. copper, luwig told me, is the direct result of feedback from hp enterprise and commercial customer who were already using the company existing headset. overwhelmingly that feedback, a ludwig said, wa resolution, resolution, resolution, followed secondarily by comfort. the former is quite satisfied by the new display (which offer surprisingly vibrant color for lcd). and while there were a few visual artifact seen through the lens (notably a diagonal array of gre ...
#  'cryptocurrency hardware wallet have become a mainstay within the digital asset economy and over the year these device have evolved. after designing the first bitcoin hardware wallet on the market, the prague based firm satoshilabs ha released a new trezor product line called the model t. the following hands on review detail how to get started with the trezor t cryptocurrency wallet and outline it primary features. in this review i also note the difference between the new version and the trezor one. the box is very well packaged compared to the trezor one i purchased year ago and come with various accesories. inside the box, there a trezor t device, a usb c cord, two recovery seed cards, a magnetic holder for the device, and a bunch of stickers. the machine itself feature a rgb lcd touchscreen display and usb communication are enabled only after authentication. one thing that is noticeable is the amount of pressure needed to insert the usb c cable. at first, i had issue initiating the firmware because my computer couldnt recognize the trezor through the cable. all shipped trezors come empty and never have firmware installed for security reasons. after choosing the t version on the website, it take you to the beta trezor browser wallet to initiate the device firmware. the setup can be initialized using the main trezor wallet insteadif you dont want to use the beta version. the t only took two minute for the firmware to install and from here i wa able to begin the wallet setup and backup process. the device screen will warn the user that a backup ha not been completed and the wallet browser will initiate the start of this process. from here, after the usual disclaimer about no screenshots and writing the seed down alone, the device screen will reveal a 12 word mnemonic seed phrase. after writing the word down on the seed card supplied in the box, i wa prompted to confirm some of the word randomly in order to verify that the seed wa written down correctly. once the device confirms that the owner ha written down the phrase, the setup move on to adding a pin to the device and a name. each action need to be confirmed using the device touchscreen. while pondering a name i decided to name my gadget satoshis trezor because, after all, we are all satoshi. moving on, the browser wallet asks if you want to add an email and i opted to skip that step. after the wallet wa all set up, i sent a small fraction of bitcoin cash (bch) to the wallet to make sure everything wa working correctly. the trezor t also support btc, btg, dash, dgb, doge, ltc, nmc, vtc, zec, ethereum, etc, xlm, xem, and ada. some of the cryptocurrency wallet like ethereum, ada, and xlm take you to a third party wallet which essentially tether the account to your device. just like the trezor one, the model t can also act a a u2f device for online account like dropbox and gmail. trezor software. overall, the model t worked well but it took me some time getting used to the usb c cord insertion, even though i use usb c hardware regularly. usb insert. after getting used to the plug, it became much easier, but you may want to use a longer cord. the lcd touchscreen display is nicebut wa not so friendly with my fat fingers. the touchscreen take some time to get used to a well and the screen is used for the wallet pin entry, instead of the onscreen randomizer pin pad used with the trezor one. the device work just a well a my first trezor wallet, but user will find subtle difference between each one. for example, the model t come with a micro sd slot for advanced feature that will be added to the operating system at a later date. even with the t touchscreen, prospective buyer may still decide to purchase version one because it significantly cheaper than the model t and just a secure. the t version is roughly $169, but that doesnt include dhl shipping costs. one thing for certain is that i will continue to use the model t hardware wallet, unlike some of the device by other manufactur ...
#  'coinflex plan to debut physically settled bitcoin future to the asian market beginning in february 2019. the platform is a consortium with participant such a roger ver (bitcoin. ceo), b2c2, trading technologies, and alameda research among others. coinflex plan to offer future contract for bitcoin, bitcoin cash, and ethereum. like bakkt (owned by intercontinental exchange), coinflexs offering are physically backed contracts. for lamb, there is great potential for expansion within the cryptocurrency future market. according to the coinflex ceo, the crypto future arena should be able to grow to 20 time the size of the spot trading market a is the case for other asset classes. presently, both market handle approximately the same volume of daily transactions. one unique detail of the coinflex offering is that contract will trade against tether (usdt), the most popular stablecoin, which is pegged against the u. s. apart from tether, coinflex also plan to launch a contract that will trade opposite circle usd coin; another stablecoin. at the expiration of the contracts, trader who hold long position will receive bitcoin, ethereum, or bitcoin cash while trader who hold short position will receive usdt depending on the performance of the contract. the reason for this is because it is incorporated offshore, allowing the platform to offer it product to a more global market except for highly regulated market like the u. s. u. k. when pressed about competition from the like of bakkt, cme, and cboe, lamb highlighted the fact that u. s. bitcoin future trading account for only a tiny portion of the market. the primary reason for this disparity stem from the fact that market like the u. s. thus u. s. asia. the coinflex chief belief btc future trading doesnt require the same level of stringent regulation like the spot trading market. where the latter offer leverage of up to 100 time on specific contracts, coinflex cap it offering at a leverage of 20 times. let u know your thought in the comment below.',
#  'goldman sachs funded cryptocurrency startup, circle, recently released it list of accomplishment for the year 2018. the company say it executed over the counter (otc) crypto trade to the tune of $24 billion in notional volume. thursday (january 3, 2019). circle trade, the otc desk of the company, executed over 10,000 otc trade worth $24 billion, it reveals. the figure published by circle are indicative of the recent trend observed in the otc arena. other major player like coinbase also show an increase in trading volume during otc hours. the $24 billion notional trading might even indicate that circle executed more otc trade than coinbase and greyscale (gbtc) combined. coinbasess otc volume at about $12 billion with $11 billion for gbtc. the acquisition of poloniex by circle wa arguably one of the significant development that occurred in 2018. poloniex, one of the largest cryptocurrency exchange platform at the time. according to circle, it ha made great effort in improving the platform compliance standards. kyc requirement introduced at the time. many legacy account holder felt the move broke several assurance provided by the company in late 2017. for circle, the step taken have yielded fruit especially in the area of customer support. the blog post revealed a 99. in 2018, the goldman sachs backed circle also acquired seedinvest a part of it drive to become a regulated broker dealer. with tightening regulation in the u crypto landscape, startup like circle and coinbase have been pursuing regulatory approval to expand their cryptocurrency product catalogs. usd coin (usdc). san francisco based exchange giant, coinbase. according to the announcement, usdc is now the second largest fiat collateralized stablecoinafter tether with a market capitalization more than $280 million. multiple cryptocurrency exchange platform also support the stablecoin. circle sixth year in existence, and the company say that it want to focus on capacity building for the industry regardless of market conditions. what do you think about circle 2018 figure despite a drop in overall prices? let u know your thought in the comment below!',
#  "ethereums (ethereum) trading range reduced on january 15, a concentration shifted to the keenly awaited constantinople upgrade expected in the next 24 hours. the hard fork, also known a the thirdening for trimming down the amount of new ethereum discharged into circulation, is anticipated to bring technical change to the globe third biggest blockchain. eths price vacillated between $127 $131 on tuesday, january 15, and is standing at $121. usd ( 5. btc) hasty swing higher. the surprise breakout and jailbreak relieved the risk of a fast move back to $100, which seemed certain at the beginning of this week, currently, there is not much resistance until around $160, a recently hard area to perforate for the bulls. even though ethereum ha faced oversized trend relative to the wider market in december or so, it more probably to trade in lockstep with is compeer since constantinople supply crunch bleached. ethereum still hold the third position both by trading volume and market capitalization. according to the market cap rankings, ethereum trail ripple (xrp) by almost $200 million. it day to day trading volume reached $2. wednesday for a one month total of over $81. coinmarketcap. it's only btc and tether (usdt) that are more actively traded. constantinople is expected to go live at block 7,080,000, although pinpointing a real moment for a hardfork is always difficult. the upgrade would probably fall between monday, january 14 and friday, january 18. january 16, 2019. the hardfork will enforce 5 ethereum improvement proposal (eip), that wallop everything from block reward to scalability. proposal eip 1234 will scale the magnitude of block reward from 3 ethereum to 2 ethereum, thus, the thirdening. in 2017, ethereum enforced the byzantium hardfork, which trimmed down the block reward from 5 ethereum to 3 ethereum. dissimilar to btc, which half the block reward for every 210,000 blocks, ethereum doesnt posse an upper cap on it circulation. therefore, trimming down block reward is meant to trim inflation by letting down the supply of newly created cryptos. the moment constantinople is live; eths inflation rate will drop from 7. ethereum supply and total inflation, according to consensys. amber data forecasting the hard fork to activate at roughly 3:30 utc thursday, january 17. a of saturday, january 12, 2019, just 16. a malicious attacker could take advantage of the vulnerability to repeatedly steal another user's ethereum out of a paymentsharer contract, according to medium."]

# %%
len(Results_Dict['Category 1'][4])
# Out:
# 10
